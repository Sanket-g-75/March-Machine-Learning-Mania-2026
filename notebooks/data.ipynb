# %%
import pandas as pd
import numpy as np
import os

import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
dir = os.getenv('DIR')
os.getcwd()
os.chdir(dir)
path = os.getcwd()

# %%
# Downloading the data directly from the Kaggle Servers
# kagglehub.competition_download('march-machine-learning-mania-2026')

# %% [markdown]
# # Merging CSV Files

# %%
os.listdir(os.path.join(path,'data','raw'))
# Out:
# ['Cities.csv',
#  'Conferences.csv',
#  'MConferenceTourneyGames.csv',
#  'MGameCities.csv',
#  'MMasseyOrdinals.csv',
#  'MNCAATourneyCompactResults.csv',
#  'MNCAATourneyDetailedResults.csv',
#  'MNCAATourneySeedRoundSlots.csv',
#  'MNCAATourneySeeds.csv',
#  'MNCAATourneySlots.csv',
#  'MRegularSeasonCompactResults.csv',
#  'MRegularSeasonDetailedResults.csv',
#  'MSeasons.csv',
#  'MSecondaryTourneyCompactResults.csv',
#  'MSecondaryTourneyTeams.csv',
#  'MTeamCoaches.csv',
#  'MTeamConferences.csv',
#  'MTeams.csv',
#  'MTeamSpellings.csv',
#  'SampleSubmissionStage1.csv',
#  'SampleSubmissionStage2.csv',
#  'WConferenceTourneyGames.csv',
#  'WGameCities.csv',
#  'WNCAATourneyCompactResults.csv',
#  'WNCAATourneyDetailedResults.csv',
#  'WNCAATourneySeeds.csv',
#  'WNCAATourneySlots.csv',
#  'WRegularSeasonCompactResults.csv',
#  'WRegularSeasonDetailedResults.csv',
#  'WSeasons.csv',
#  'WSecondaryTourneyCompactResults.csv',
#  'WSecondaryTourneyTeams.csv',
#  'WTeamConferences.csv',
#  'WTeams.csv',
#  'WTeamSpellings.csv']

# %% [markdown]
# ## Merging Men and Women Files

# %%
# Teams

teams = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MTeams.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WTeams.csv')).assign(Gender='W')
    ]
)

# %%
teamconferences = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MTeamConferences.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WTeamConferences.csv')).assign(Gender='W')
    ]
)

# %%
ncaatourneyseeds = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MNCAATourneySeeds.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WNCAATourneySeeds.csv')).assign(Gender='W')
    ]
)

# %%
secondarytourneyteams = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MSecondaryTourneyTeams.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WSecondaryTourneyTeams.csv')).assign(Gender='W')
    ]
)

# %%
secondarytourneycompactresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MSecondaryTourneyCompactResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WSecondaryTourneyCompactResults.csv')).assign(Gender='W')
    ]
)

# %%
ncaatourneycompactresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MNCAATourneyCompactResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WNCAATourneyCompactResults.csv')).assign(Gender='W')
    ]
)

# %%
ncaatourneydetailedresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MNCAATourneyDetailedResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WNCAATourneyDetailedResults.csv')).assign(Gender='W')
    ]
)

# %%
gamecities = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MGameCities.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WGameCities.csv')).assign(Gender='W')
    ]
)

# %%
seasons = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MSeasons.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WSeasons.csv')).assign(Gender='W')
    ]
)

# %%
conferencetourneygames = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MConferenceTourneyGames.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WConferenceTourneyGames.csv')).assign(Gender='W')
    ]
)

# %%
regularseasoncompactresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MRegularSeasonCompactResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WRegularSeasonCompactResults.csv')).assign(Gender='W')
    ]
)

# %%
regularseasondetailedresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MRegularSeasonDetailedResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WRegularSeasonDetailedResults.csv')).assign(Gender='W')
    ]
)

# %%
secondarytourneycompactresults = pd.concat(
    [
    pd.read_csv(os.path.join(path,'data','raw','MSecondaryTourneyCompactResults.csv')).assign(Gender='M'),
    pd.read_csv(os.path.join(path,'data','raw','WSecondaryTourneyCompactResults.csv')).assign(Gender='W')
    ]
)

# %%
teams.to_csv(os.path.join(path,'data','processed','Teams.csv'))
teamconferences.to_csv(os.path.join(path,'data','processed','TeamConfereces.csv'))
ncaatourneyseeds.to_csv(os.path.join(path,'data','processed','NCAATourneySeeds.csv'))
secondarytourneyteams.to_csv(os.path.join(path,'data','processed','SecondaryTourneyTeams.csv'))
ncaatourneycompactresults.to_csv(os.path.join(path,'data','processed','NCAATourneyCompactResults.csv'))
ncaatourneydetailedresults.to_csv(os.path.join(path,'data','processed','NCAATourneyDetailedResults.csv'))
gamecities.to_csv(os.path.join(path,'data','processed','GameCities.csv'))
seasons.to_csv(os.path.join(path,'data','processed','Seasons.csv'))
conferencetourneygames.to_csv(os.path.join(path,'data','processed','ConferenceTourneyGames.csv'))
regularseasoncompactresults.to_csv(os.path.join(path,'data','processed','RegularSeasonCompactResults.csv'))
regularseasondetailedresults.to_csv(os.path.join(path,'data','processed','RegularSeasonDetailedResults.csv'))
secondarytourneycompactresults.to_csv(os.path.join(path,'data','processed','SecondaryTourneyCompactResults.csv'))

# %%
# Also append the remaining useful files to processed folder to use them for computation

coaches = pd.read_csv(os.path.join(path,'data','raw','MTeamCoaches.csv')).assign(Gender='M')
coaches.to_csv(os.path.join(path,'data','processed','Coaches.csv'))

masseyordinals = pd.read_csv(os.path.join(path,'data','raw','MMasseyOrdinals.csv')).assign(Gender='M')
masseyordinals.to_csv(os.path.join(path,'data','processed','MasseyOrdinals.csv'))

# %% [markdown]
# ## Merging based on Keys

# %% [markdown]
# > Key = Season, Daynum, WTeamID, LTeamID, Gender
#
# * NCAATournamentSessionDetailedResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames
# ---
# * RegularSessionDetailedResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames
# ---
# * SecondaryTourneyCompactResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames

# %%
ncaa = pd.read_csv(os.path.join(path,'data','processed','NCAATourneyDetailedResults.csv'))
ncaa.drop(columns='Unnamed: 0',inplace=True)

regular = pd.read_csv(os.path.join(path,'data','processed','RegularSeasonDetailedResults.csv'))
regular.drop(columns='Unnamed: 0',inplace=True)

# secondary = pd.read_csv(os.path.join(path,'data','processed','RegularSeasonDetailedResults.csv'))

cities = pd.read_csv(os.path.join(path,'data','processed','GameCities.csv'))
cities.drop(columns='Unnamed: 0',inplace=True)



conferencetourneygames = pd.read_csv(os.path.join(path,'data','processed','ConferenceTourneyGames.csv'))
conferencetourneygames.drop(columns='Unnamed: 0',inplace=True)

# %%
# NCAA
data = ncaa.merge(cities,on=['Season','DayNum','WTeamID','LTeamID','Gender'],how='left')
data = data.merge(conferencetourneygames,on=['Season','DayNum','WTeamID','LTeamID','Gender'],how='left')

# %%
# Regular
data2 = regular.merge(cities,on=['Season','DayNum','WTeamID','LTeamID','Gender'],how='left')
data2 = data2.merge(conferencetourneygames,on=['Season','DayNum','WTeamID','LTeamID','Gender'],how='left')

# %%
data
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2003     134     1421      92     1411      84    N      1    32
# 1       2003     136     1112      80     1436      51    N      0    31
# 2       2003     136     1113      84     1272      71    N      0    31
# 3       2003     136     1141      79     1166      73    N      0    29
# 4       2003     136     1143      76     1301      74    N      1    27
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 2405    2025     147     3163      78     3425      64    N      0    27
# 2406    2025     147     3400      58     3395      47    N      0    24
# 2407    2025     151     3163      85     3417      51    N      0    33
# 2408    2025     151     3376      74     3400      57    N      0    29
# 2409    2025     153     3163      82     3376      59    N      0    30
#
#       WFGA  ...  LDR  LAst  LTO  LStl  LBlk  LPF  Gender  CRType  CityID  \
# 0       69  ...   28    16   15     5     0   22       M     NaN     NaN
# 1       66  ...   26    12   17    10     3   15       M     NaN     NaN
# 2       59  ...   22    11   12     2     5   18       M     NaN     NaN
# 3       53  ...   17    20   21     6     6   21       M     NaN     NaN
# 4       64  ...   26    16   14     5     8   19       M     NaN     NaN
# ...    ...  ...  ...   ...  ...   ...   ...  ...     ...     ...     ...
# 2405    60  ...   29     7   15     8     2   18       W    NCAA  4324.0
# 2406    61  ...   27     8   21     1     3   14       W    NCAA  4030.0
# 2407    60  ...   21    11   19     5     2   12       W    NCAA  4342.0
# 2408    57  ...   20    10   14     6     5   17       W    NCAA  4342.0
# 2409    62  ...   19     9   11     6     4   17       W    NCAA  4342.0
#
#       ConfAbbrev
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2405         NaN
# 2406         NaN
# 2407         NaN
# 2408         NaN
# 2409         NaN
#
# [2410 rows x 38 columns]

# %%
data2
# Out:
#         Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0         2003      10     1104      68     1328      62    N      0    27
# 1         2003      10     1272      70     1393      63    N      0    26
# 2         2003      11     1266      73     1437      61    N      0    24
# 3         2003      11     1296      56     1457      50    N      0    18
# 4         2003      11     1400      77     1208      71    N      0    30
# ...        ...     ...      ...     ...      ...     ...  ...    ...   ...
# 210799    2026     118     3435      87     3397      77    A      0    35
# 210800    2026     118     3439      83     3438      82    A      0    27
# 210801    2026     118     3449      70     3332      69    A      0    27
# 210802    2026     118     3452     118     3153      60    H      0    42
# 210803    2026     118     3456      60     3423      41    A      0    22
#
#         WFGA  ...  LDR  LAst  LTO  LStl  LBlk  LPF  Gender   CRType  CityID  \
# 0         58  ...   22     8   18     9     2   20       M      NaN     NaN
# 1         62  ...   25     7   12     8     6   16       M      NaN     NaN
# 2         58  ...   22     9   12     2     5   23       M      NaN     NaN
# 3         38  ...   20     9   19     4     3   23       M      NaN     NaN
# 4         61  ...   15    12   10     7     1   14       M      NaN     NaN
# ...      ...  ...  ...   ...  ...   ...   ...  ...     ...      ...     ...
# 210799    66  ...   20     9    7     2    13   14       W  Regular  4180.0
# 210800    65  ...   22    15    4     3    14   19       W  Regular  4067.0
# 210801    59  ...   20    13    6     2    14   16       W  Regular  4112.0
# 210802    72  ...   19     9    2     1    17   25       W  Regular  4224.0
# 210803    61  ...   19     8    6     5    20   17       W  Regular  4370.0
#
#         ConfAbbrev
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 210799         NaN
# 210800         NaN
# 210801         NaN
# 210802         NaN
# 210803         NaN
#
# [210804 rows x 38 columns]

# %%
data.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'Gender', 'CRType', 'CityID', 'ConfAbbrev'],
#       dtype='object')

# %%
# first I will have to separate winners and losers
dataw = data[['Season', 'DayNum', 'WTeamID', 'WScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF','Gender', 'CRType', 'CityID', 'ConfAbbrev']]

datal = data[['Season', 'DayNum','LTeamID', 'LScore',
              'NumOT', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3','LFTM', 'LFTA', 'LOR', 'LDR',
              'LAst', 'LTO', 'LStl', 'LBlk', 'LPF','Gender', 'CRType', 'CityID', 'ConfAbbrev']]

dataw.rename(columns={'WTeamID':'TeamID'},inplace=True)
datal.rename(columns={'LTeamID':'TeamID'},inplace=True)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_36392\3410070390.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datal.rename(columns={'LTeamID':'TeamID'},inplace=True)

# %%
data2w = data2[['Season', 'DayNum', 'WTeamID', 'WScore', 'WLoc',
       'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
       'WAst', 'WTO', 'WStl', 'WBlk', 'WPF','Gender', 'CRType', 'CityID', 'ConfAbbrev']]

data2l = data2[['Season', 'DayNum','LTeamID', 'LScore',
              'NumOT', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3','LFTM', 'LFTA', 'LOR', 'LDR',
              'LAst', 'LTO', 'LStl', 'LBlk', 'LPF','Gender', 'CRType', 'CityID', 'ConfAbbrev']]

data2w.rename(columns={'WTeamID':'TeamID'},inplace=True)
data2l.rename(columns={'LTeamID':'TeamID'},inplace=True)
# Out:
# C:\Users\Sanket\AppData\Local\Temp\ipykernel_36392\2922518759.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2l.rename(columns={'LTeamID':'TeamID'},inplace=True)

# %% [markdown]
# > Key = TeamID, Seasons, Gender
# * NCAATourneySeeds   # No seeds for Secondary and Regular games
# * MasseyOrdinals   # Only for Men
# * TeamCoaches      # Only for Men
# * TeamConferences

# %%
ncaatourneyseeds = pd.read_csv(os.path.join(path,'data','processed','NCAATourneySeeds.csv'))
massey = pd.read_csv(os.path.join(path,'data','processed','MasseyOrdinals.csv'))
teamcoaches = pd.read_csv(os.path.join(path,'data','processed','Coaches.csv'))
teamconferences = pd.read_csv(os.path.join(path,'data','processed','TeamConfereces.csv'))

# %%
teamconferences.drop(columns='Unnamed: 0',inplace=True)

# %%
dataw = dataw.merge(ncaatourneyseeds,on=['Season','TeamID','Gender'],how='left')
dataw = dataw.merge(massey,on=['Season','TeamID','Gender'],how='left')
dataw = dataw.merge(teamcoaches,on=['Season','TeamID','Gender'],how='left')
dataw = dataw.merge(teamconferences,on=['Season','TeamID','Gender'],how='left')

# %%
datal = datal.merge(ncaatourneyseeds,on=['Season','TeamID','Gender'],how='left')
datal = datal.merge(massey,on=['Season','TeamID','Gender'],how='left')
datal = datal.merge(teamcoaches,on=['Season','TeamID','Gender'],how='left')
datal = datal.merge(teamconferences,on=['Season','TeamID','Gender'],how='left')

# %%
# data2w = data2w.merge(massey,on=['Season','TeamID','Gender'],how='left',indicator=True)
data2w = data2w.merge(teamcoaches,on=['Season','TeamID','Gender'],how='left')
data2w = data2w.merge(teamconferences,on=['Season','TeamID','Gender'],how='left')

# %%
# data2l = data2l.merge(massey,on=['Season','TeamID','Gender'],how='inner')
data2l = data2l.merge(teamcoaches,on=['Season','TeamID','Gender'],how='left')
data2l = data2l.merge(teamconferences,on=['Season','TeamID','Gender'],how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 data2l = data2l.merge(massey,on=['Season','TeamID','Gender'],how='inner')
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\frame.py:10859, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10840 @Substitution("")
#   10841 @Appender(_merge_doc, indents=2)
#   10842 def merge(
#    (...)
#   10855     validate: MergeValidate | None = None,
#   10856 ) -> DataFrame:
#   10857     from pandas.core.reshape.merge import merge
# > 10859     return merge(
#   10860         self,
#   10861         right,
#   10862         how=how,
#   10863         on=on,
#   10864         left_on=left_on,
#   10865         right_on=right_on,
#   10866         left_index=left_index,
#   10867         right_index=right_index,
#   10868         sort=sort,
#   10869         suffixes=suffixes,
#   10870         copy=copy,
#   10871         indicator=indicator,
#   10872         validate=validate,
#   10873     )
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:879, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     877 left.columns = llabels
#     878 right.columns = rlabels
# --> 879 result = concat([left, right], axis=1, copy=copy)
#     880 return result
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)
#     227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:612, in BaseBlockManager.copy(self, deep)
#     609     else:
#     610         new_axes = list(self.axes)
# --> 612 res = self.apply("copy", deep=deep)
#     613 res.axes = new_axes
#     615 if self.ndim > 1:
#     616     # Avoid needing to re-compute these
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:822, in Block.copy(self, deep)
#     820 refs: BlockValuesRefs | None
#     821 if deep:
# --> 822     values = values.copy()
#     823     refs = None
#     824 else:
#
# MemoryError: Unable to allocate 2.62 GiB for an array with shape (4, 87925840) and data type float64

# %%
chunks = []
for chunk in pd.read_csv(os.path.join(path,'data','processed','MasseyOrdinals.csv'), chunksize=3000):
    merged = pd.merge(chunk, data2l, on=['TeamID','Season','Gender'], how='inner')
    chunks.append(merged)
data2l = pd.concat(chunks, ignore_index=True)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.12.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
chunks = []
for chunk in pd.read_csv(os.path.join(path,'data','processed','MasseyOrdinals.csv'), chunksize=500000):
    merged = pd.merge(chunk, data2w, on=['TeamID','Season','Gender'], how='inner')
    chunks.append(merged)
data2w = pd.concat(chunks, ignore_index=True)

# %%
data2w
# Out:
#         Season  DayNum  TeamID  WScore WLoc  NumOT  WFGM  WFGA  WFGM3  WFGA3  \
# 0         2003      10    1104      68    N      0    27    58      3     14
# 1         2003      10    1272      70    N      0    26    62      8     20
# 2         2003      11    1266      73    N      0    24    58      8     18
# 3         2003      11    1296      56    N      0    18    38      3      9
# 4         2003      11    1400      77    N      0    30    61      6     14
# ...        ...     ...     ...     ...  ...    ...   ...   ...    ...    ...
# 211613    2026     118    3435      87    A      0    35    66     11     22
# 211614    2026     118    3439      83    A      0    27    65     10     26
# 211615    2026     118    3449      70    A      0    27    59      9     27
# 211616    2026     118    3452     118    H      0    42    72     15     30
# 211617    2026     118    3456      60    A      0    22    61      6     18
#
#         ...  WPF  Gender   CRType  CityID  ConfAbbrev_x  Unnamed: 0  \
# 0       ...   22       M      NaN     NaN           NaN      5462.0
# 1       ...   18       M      NaN     NaN           NaN      5616.0
# 2       ...   25       M      NaN     NaN           NaN      5610.0
# 3       ...   18       M      NaN     NaN           NaN      5638.0
# 4       ...   20       M      NaN     NaN           NaN      5730.0
# ...     ...  ...     ...      ...     ...           ...         ...
# 211613  ...   14       W  Regular  4180.0           NaN         NaN
# 211614  ...   24       W  Regular  4067.0           NaN         NaN
# 211615  ...   17       W  Regular  4112.0           NaN         NaN
# 211616  ...   20       W  Regular  4224.0           NaN         NaN
# 211617  ...   15       W  Regular  4370.0           NaN         NaN
#
#         FirstDayNum  LastDayNum       CoachName ConfAbbrev_y
# 0               0.0       154.0  mark_gottfried          sec
# 1               0.0       154.0   john_calipari         cusa
# 2               0.0       154.0       tom_crean         cusa
# 3               0.0       154.0      rob_judson          mac
# 4               0.0       154.0     rick_barnes   big_twelve
# ...             ...         ...             ...          ...
# 211613          NaN         NaN             NaN          sec
# 211614          NaN         NaN             NaN          acc
# 211615          NaN         NaN             NaN      big_ten
# 211616          NaN         NaN             NaN   big_twelve
# 211617          NaN         NaN             NaN          caa
#
# [211618 rows x 28 columns]

# %% [markdown]
# # Feature Engineering

# %%
ncaad
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2003     134     1421      92     1411      84    N      1    32
# 1       2003     136     1112      80     1436      51    N      0    31
# 2       2003     136     1113      84     1272      71    N      0    31
# 3       2003     136     1141      79     1166      73    N      0    29
# 4       2003     136     1143      76     1301      74    N      1    27
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 2405    2025     147     3163      78     3425      64    N      0    27
# 2406    2025     147     3400      58     3395      47    N      0    24
# 2407    2025     151     3163      85     3417      51    N      0    33
# 2408    2025     151     3376      74     3400      57    N      0    29
# 2409    2025     153     3163      82     3376      59    N      0    30
#
#       WFGA  ...  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF  Gender
# 0       69  ...    14    31   17   28    16   15     5     0   22       M
# 1       66  ...     7     7    8   26    12   17    10     3   15       M
# 2       59  ...    14    21   20   22    11   12     2     5   18       M
# 3       53  ...    12    17   14   17    20   21     6     6   21       M
# 4       64  ...    15    20   10   26    16   14     5     8   19       M
# ...    ...  ...   ...   ...  ...  ...   ...  ...   ...   ...  ...     ...
# 2405    60  ...    23    26   13   29     7   15     8     2   18       W
# 2406    61  ...    19    21   11   27     8   21     1     3   14       W
# 2407    60  ...     7     8    8   21    11   19     5     2   12       W
# 2408    57  ...     9    12    9   20    10   14     6     5   17       W
# 2409    62  ...    13    18   17   19     9   11     6     4   17       W
#
# [2410 rows x 35 columns]

# %%
ncaa = pd.read_csv(os.path.join(path,'data','processed','NCAATourneyDetailedResults.csv'))
regular = pd.read_csv(os.path.join(path,'data','processed','RegularSeasonDetailedResults.csv'))
# Compact is not needed as everything is already in the DetailedReport

# %%
ncaa.drop(columns='Unnamed: 0',inplace=True)
regular.drop(columns='Unnamed: 0',inplace=True)

# %%
# NCAA
# [i for i in data.columns if i.startswith('L')]
winners = ['Season','DayNum','WTeamID','WScore','WLoc','NumOT','WFGM','WFGA','WFGM3','WFGA3','WFTM','WFTA','WOR','WDR','WAst','WTO','WStl','WBlk','WPF','Gender']
losers =  ['Season','DayNum','LTeamID','LScore','WLoc','NumOT','LFGM','LFGA','LFGM3','LFGA3','LFTM','LFTA','LOR','LDR','LAst','LTO','LStl','LBlk','LPF','Gender']
# Out:
# ['LTeamID',
#  'LScore',
#  'LFGM',
#  'LFGA',
#  'LFGM3',
#  'LFGA3',
#  'LFTM',
#  'LFTA',
#  'LOR',
#  'LDR',
#  'LAst',
#  'LTO',
#  'LStl',
#  'LBlk',
#  'LPF']

# %%
ncaa.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'Gender'],
#       dtype='object')

# %%
regular.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'Gender'],
#       dtype='object')

# %%
massey = pd.read_csv(os.path.join(path,'data','processed','MasseyOrdinals.csv'))

# %%
massey
# Out:
#          Unnamed: 0  Season  RankingDayNum SystemName  TeamID  OrdinalRank  \
# 0                 0    2003             35        SEL    1102          159
# 1                 1    2003             35        SEL    1103          229
# 2                 2    2003             35        SEL    1104           12
# 3                 3    2003             35        SEL    1105          314
# 4                 4    2003             35        SEL    1106          260
# ...             ...     ...            ...        ...     ...          ...
# 5819223     5819223    2026            114        WOL    1477          282
# 5819224     5819224    2026            114        WOL    1478          292
# 5819225     5819225    2026            114        WOL    1479          307
# 5819226     5819226    2026            114        WOL    1480          286
# 5819227     5819227    2026            114        WOL    1481          308
#
#         Gender
# 0            M
# 1            M
# 2            M
# 3            M
# 4            M
# ...        ...
# 5819223      M
# 5819224      M
# 5819225      M
# 5819226      M
# 5819227      M
#
# [5819228 rows x 7 columns]
