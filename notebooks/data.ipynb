# %%
import pandas as pd
import numpy as np
import os

import kagglehub

# %%
os.getcwd()
os.chdir(f'd:\\1.Work\\WorkStation\\WorkSpace\\Projects\\March-Machine-Learning-Mania-2026')
path = os.getcwd()

# %%
kagglehub.competition_download('march-machine-learning-mania-2026',path=os.path.join(path,'data'))
# Out:
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 kagglehub.competition_download('march-machine-learning-mania-2026',path=os.path.join(path,'data'))
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\kagglehub\competition.py:23, in competition_download(handle, path, force_download)
#      21 h = parse_competition_handle(handle)
#      22 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 23 path, _ = registry.competition_resolver(h, path, force_download=force_download)
#      24 return path
#
# File c:\Users\Sanket\anaconda3\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
# ...
