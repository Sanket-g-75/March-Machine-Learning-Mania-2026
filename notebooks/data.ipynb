# %%
import pandas as pd
import numpy as np
import os


from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
dir = os.getenv('DIR')
os.getcwd()
os.chdir(dir)
path = os.getcwd()

# %%
# Downloading the data directly from the Kaggle Servers
# kagglehub.competition_download('march-machine-learning-mania-2026')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/march-machine-learning-mania-2026...
# 100%|██████████| 34.6M/34.6M [00:08<00:00, 4.22MB/s]
# Extracting files...
# 'C:\\Users\\Sanket\\.cache\\kagglehub\\competitions\\march-machine-learning-mania-2026'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Merging CSV Files

# %%
os.listdir(os.path.join(path,'data','raw'))
# Out:
# ['Cities.csv',
#  'Conferences.csv',
#  'MConferenceTourneyGames.csv',
#  'MGameCities.csv',
#  'MMasseyOrdinals.csv',
#  'MNCAATourneyCompactResults.csv',
#  'MNCAATourneyDetailedResults.csv',
#  'MNCAATourneySeedRoundSlots.csv',
#  'MNCAATourneySeeds.csv',
#  'MNCAATourneySlots.csv',
#  'MRegularSeasonCompactResults.csv',
#  'MRegularSeasonDetailedResults.csv',
#  'MSeasons.csv',
#  'MSecondaryTourneyCompactResults.csv',
#  'MSecondaryTourneyTeams.csv',
#  'MTeamCoaches.csv',
#  'MTeamConferences.csv',
#  'MTeams.csv',
#  'MTeamSpellings.csv',
#  'SampleSubmissionStage1.csv',
#  'SampleSubmissionStage2.csv',
#  'WConferenceTourneyGames.csv',
#  'WGameCities.csv',
#  'WNCAATourneyCompactResults.csv',
#  'WNCAATourneyDetailedResults.csv',
#  'WNCAATourneySeeds.csv',
#  'WNCAATourneySlots.csv',
#  'WRegularSeasonCompactResults.csv',
#  'WRegularSeasonDetailedResults.csv',
#  'WSeasons.csv',
#  'WSecondaryTourneyCompactResults.csv',
#  'WSecondaryTourneyTeams.csv',
#  'WTeamConferences.csv',
#  'WTeams.csv',
#  'WTeamSpellings.csv']

# %% [markdown]
# > Key = TeamID
#
# * teams
# * Conferences
#
# > Key = TeamID, Seasons
#
# * NCAATourneySeeds
# * MasseyOrdinals
# * TeamCoaches
# * TeamConferences
# * SecondaryTourneyTeams
#
# * RegularSessioTourneySeeds
# * TeamCoaches
# * MasseyOrdinals
# * TeamConferences
# * SecondaryTourneyTeams
#
# * SecondaryTourneySeeds
# * TeamCoaches
# * MasseyOrdinals
# * TeamConferences
# * SecondaryTourneyTeams
#
# > Key = Season, Daynum, WTeamID, LTeamID
#
# * RegularSessionCompactResults
# * RegularSessionDetailedResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames
#
# * NCAATournamentSessionCompactResults
# * NCAATournamentSessionDetailedResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames
#
# * SecondaryTourneyCompactResults
# * SecondaryTourneyDetailedResults
# * GameCities
# * Seasons
# * ConferenceTourneyGames
#
#
# > Not Needed
# * Conferences
# * TeamSpellings
# * NCAATourneySlots
# * Seasons
# * Cities
# * NCAATourneySeedRoundSlots
